# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\HP\Desktop\BankChurners.csv\Data.xlsx')
df
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45213 entries, 0 to 45212
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   banking marketing  45213 non-null  object
#  1   Unnamed: 1         45192 non-null  object
#  2   Unnamed: 2         45213 non-null  object
#  3   Unnamed: 3         45212 non-null  object
#  4   Unnamed: 4         45213 non-null  object
#  5   Unnamed: 5         45212 non-null  object
#  6   Unnamed: 6         45213 non-null  object
#  7   Unnamed: 7         45212 non-null  object
#  8   Unnamed: 8         45213 non-null  object
#  9   Unnamed: 9         45212 non-null  object
#  10  Unnamed: 10        45213 non-null  object
#  11  Unnamed: 11        45212 non-null  object
#  12  Unnamed: 12        45163 non-null  object
#  13  Unnamed: 13        45213 non-null  object
#  14  Unnamed: 14        45212 non-null  object
#  15  Unnamed: 15        45212 non-null  object
# ...

# %%
df
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
df.max()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Unnamed: 4               single
# Unnamed: 6                  yes
# Unnamed: 8                  yes
# Unnamed: 10             unknown
# Unnamed: 13    duration of call
# Unnamed: 17             unknown
# dtype: object

# %%
df.min()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Unnamed: 4     Customer marital status and job with education...
# Unnamed: 6                                                    no
# Unnamed: 8                    Loan types: loans or housing loans
# Unnamed: 10                                         Contact type
# Unnamed: 13                                                0 min
# Unnamed: 17                                              failure
# dtype: object

# %%
df.sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Unnamed: 4     Customer marital status and job with education...
# Unnamed: 6     particular customer before targeted or nottarg...
# Unnamed: 8     Loan types: loans or housing loanshousingyesye...
# Unnamed: 10    Contact typecontactunknownunknownunknownunknow...
# Unnamed: 13    duration of callduration261 sec151 sec76 sec92...
# Unnamed: 17    outcome of previous contactpoutcomeunknownunkn...
# dtype: object

# %%
df.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
df.tail()
# Out:
#       banking marketing Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 45208             45207         51      60000        825    married
# 45209             45208         71      55000       1729   divorced
# 45210             45209         72      55000       5715    married
# 45211             45210         57      20000        668    married
# 45212             45211         37     120000       2971    married
#
#                    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 45208     technician,tertiary        yes         no         no         no
# 45209         retired,primary        yes         no         no         no
# 45210       retired,secondary        yes         no         no         no
# 45211   blue-collar,secondary        yes         no         no         no
# 45212  entrepreneur,secondary        yes         no         no         no
#
#       Unnamed: 10 Unnamed: 11 Unnamed: 12           Unnamed: 13 Unnamed: 14  \
# ...

# %%
df.set_index('Unnamed: 1')
# Out:
#                banking marketing                    Unnamed: 2 Unnamed: 3  \
# Unnamed: 1
# NaN         customer id and age.  Customer salary and balance.        NaN
# age                   customerid                        salary    balance
# 58                             1                        100000       2143
# 44                             2                         60000         29
# 33                             3                        120000          2
# ...                          ...                           ...        ...
# 51                         45207                         60000        825
# 71                         45208                         55000       1729
# 72                         45209                         55000       5715
# 57                         45210                         20000        668
# 37                         45211                        120000       2971
#
#                                                    Unnamed: 4  \
# ...

# %%
df.set_index('Unnamed: 2')
# Out:
#                                  banking marketing Unnamed: 1 Unnamed: 3  \
# Unnamed: 2
# Customer salary and balance.  customer id and age.        NaN        NaN
# salary                                  customerid        age    balance
# 100000                                           1         58       2143
# 60000                                            2         44         29
# 120000                                           3         33          2
# ...                                            ...        ...        ...
# 60000                                        45207         51        825
# 55000                                        45208         71       1729
# 55000                                        45209         72       5715
# 20000                                        45210         57        668
# 120000                                       45211         37       2971
#
# ...

# %%
df.set_index('Unnamed: 7')
# Out:
#                banking marketing Unnamed: 1                    Unnamed: 2  \
# Unnamed: 7
# NaN         customer id and age.        NaN  Customer salary and balance.
# default               customerid        age                        salary
# no                             1         58                        100000
# no                             2         44                         60000
# no                             3         33                        120000
# ...                          ...        ...                           ...
# no                         45207         51                         60000
# no                         45208         71                         55000
# no                         45209         72                         55000
# no                         45210         57                         20000
# no                         45211         37                        120000
#
# ...

# %%
df.set_index('banking marketing')
# Out:
#                      Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# banking marketing
# customer id and age.        NaN  Customer salary and balance.        NaN
# customerid                  age                        salary    balance
# 1                            58                        100000       2143
# 2                            44                         60000         29
# 3                            33                        120000          2
# ...                         ...                           ...        ...
# 45207                        51                         60000        825
# 45208                        71                         55000       1729
# 45209                        72                         55000       5715
# 45210                        57                         20000        668
# 45211                        37                        120000       2971
#
# ...

# %%
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Series([], dtype: float64)

# %%
df.median()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Series([], dtype: float64)

# %%
df.var()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Series([], dtype: float64)

# %%
df.std()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Series([], dtype: float64)

# %%
df.describe()
# Out:
#            banking marketing  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# count                  45213       45192       45213       45212      45213
# unique                 45213          78          14        7169          5
# top     customer id and age.          32       20000           0    married
# freq                       1        2085        9732        3514      27214
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# count                 45212      45213      45212      45213      45212
# unique                   49          4          3          4          3
# top     management,tertiary        yes         no        yes         no
# freq                   7801      37091      44396      25130      37967
#
#        Unnamed: 10  Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# count        45213        45212       45163       45213        45212
# unique           5           32          14        2648           49
# ...

# %%
df.describe(include='all')
# Out:
#            banking marketing  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# count                  45213       45192       45213       45212      45213
# unique                 45213          78          14        7169          5
# top     customer id and age.          32       20000           0    married
# freq                       1        2085        9732        3514      27214
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# count                 45212      45213      45212      45213      45212
# unique                   49          4          3          4          3
# top     management,tertiary        yes         no        yes         no
# freq                   7801      37091      44396      25130      37967
#
#        Unnamed: 10  Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# count        45213        45212       45163       45213        45212
# unique           5           32          14        2648           49
# ...

# %%
df.shape
# Out:
# (45213, 19)

# %%
df.columns
# Out:
# Index(['banking marketing', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
df['Unnamed: 4'].value_counts()
# Out:
# married                                                  27214
# single                                                   12790
# divorced                                                  5207
# Customer marital status and job with education level.        1
# marital                                                      1
# Name: Unnamed: 4, dtype: int64

# %%
df['Unnamed: 5'].value_counts()
# Out:
# management,tertiary        7801
# blue-collar,secondary      5371
# technician,secondary       5229
# admin.,secondary           4219
# blue-collar,primary        3758
# services,secondary         3457
# technician,tertiary        1968
# management,secondary       1121
# retired,secondary           984
# self-employed,tertiary      833
# retired,primary             795
# unemployed,secondary        728
# entrepreneur,tertiary       686
# housemaid,primary           627
# self-employed,secondary     577
# admin.,tertiary             572
# entrepreneur,secondary      542
# student,secondary           508
# blue-collar,unknown         454
# housemaid,secondary         395
# retired,tertiary            366
# services,primary            345
# management,primary          294
# unemployed,tertiary         289
# unemployed,primary          257
# management,unknown          242
# technician,unknown          242
# student,tertiary            223
# admin.,primary              209
# ...

# %%
df['banking marketing'].value_counts()
# Out:
# customer id and age.    1
# 30200                   1
# 30136                   1
# 30137                   1
# 30138                   1
#                        ..
# 15072                   1
# 15073                   1
# 15074                   1
# 15075                   1
# 45211                   1
# Name: banking marketing, Length: 45213, dtype: int64

# %%
df.set_index('Unnamed: 5')
# Out:
#                            banking marketing Unnamed: 1  \
# Unnamed: 5
# NaN                     customer id and age.        NaN
# jobedu                            customerid        age
# management,tertiary                        1         58
# technician,secondary                       2         44
# entrepreneur,secondary                     3         33
# ...                                      ...        ...
# technician,tertiary                    45207         51
# retired,primary                        45208         71
# retired,secondary                      45209         72
# blue-collar,secondary                  45210         57
# entrepreneur,secondary                 45211         37
#
#                                           Unnamed: 2 Unnamed: 3  \
# Unnamed: 5
# NaN                     Customer salary and balance.        NaN
# jobedu                                        salary    balance
# management,tertiary                           100000       2143
# ...

# %%
df.sort_index()
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 45212                 45211         37                        120000
# 45211                 45210         57                         20000
# 45210                 45209         72                         55000
# 45209                 45208         71                         55000
# 45208                 45207         51                         60000
# ...                     ...        ...                           ...
# 4                         3         33                        120000
# 3                         2         44                         60000
# 2                         1         58                        100000
# 1                customerid        age                        salary
# 0      customer id and age.        NaN  Customer salary and balance.
#
#       Unnamed: 3                                         Unnamed: 4  \
# 45212       2971                                            married
# ...

# %%
df['Unnamed: 2'].unique()
# Out:
# array(['Customer salary and balance.', 'salary', 100000, 60000, 120000,
#        20000, 0, 55000, 50000, 70000, 8000, 16000, 4000, '?'],
#       dtype=object)

# %%
df['banking marketing'].unique()
# Out:
# array(['customer id and age.', 'customerid', 1, ..., 45209, 45210, 45211],
#       dtype=object)

# %%
df['Unnamed: 5'].unique()
# Out:
# array([nan, 'jobedu', 'management,tertiary', 'technician,secondary',
#        'entrepreneur,secondary', 'blue-collar,unknown', 'unknown,unknown',
#        'entrepreneur,tertiary', 'retired,primary', 'admin.,secondary',
#        'technician,unknown', 'services,secondary', 'admin.,unknown',
#        'blue-collar,primary', 'blue-collar,secondary',
#        'management,secondary', 'retired,secondary', 'retired,unknown',
#        'admin.,primary', 'self-employed,tertiary', 'services,primary',
#        'admin.,tertiary', 'retired,tertiary', 'technician,tertiary',
#        'self-employed,primary', 'technician,primary',
#        'management,unknown', 'unemployed,tertiary', 'services,unknown',
#        'housemaid,primary', 'self-employed,secondary',
#        'unemployed,secondary', 'student,secondary',
#        'entrepreneur,unknown', 'services,tertiary', 'student,unknown',
#        'unemployed,unknown', 'entrepreneur,primary', 'student,tertiary',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['banking marketing']
# Out:
# 0        customer id and age.
# 1                  customerid
# 2                           1
# 3                           2
# 4                           3
#                  ...
# 45208                   45207
# 45209                   45208
# 45210                   45209
# 45211                   45210
# 45212                   45211
# Name: banking marketing, Length: 45213, dtype: object

# %%
df.iloc[8]
# Out:
# banking marketing                      7
# Unnamed: 1                            28
# Unnamed: 2                        100000
# Unnamed: 3                           447
# Unnamed: 4                        single
# Unnamed: 5           management,tertiary
# Unnamed: 6                            no
# Unnamed: 7                            no
# Unnamed: 8                           yes
# Unnamed: 9                           yes
# Unnamed: 10                      unknown
# Unnamed: 11                            5
# Unnamed: 12                    may, 2017
# Unnamed: 13                      217 sec
# Unnamed: 14                            1
# Unnamed: 15                           -1
# Unnamed: 16                            0
# Unnamed: 17                      unknown
# Unnamed: 18                           no
# Name: 8, dtype: object

# %%
df.iloc[1,2:4]
# Out:
# Unnamed: 2     salary
# Unnamed: 3    balance
# Name: 1, dtype: object

# %%
df.iloc[1:3,1:4]
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3
# 1        age     salary    balance
# 2         58     100000       2143

# %%
df.iloc[5,:]
# Out:
# banking marketing                      4
# Unnamed: 1                            47
# Unnamed: 2                         20000
# Unnamed: 3                          1506
# Unnamed: 4                       married
# Unnamed: 5           blue-collar,unknown
# Unnamed: 6                            no
# Unnamed: 7                            no
# Unnamed: 8                           yes
# Unnamed: 9                            no
# Unnamed: 10                      unknown
# Unnamed: 11                            5
# Unnamed: 12                    may, 2017
# Unnamed: 13                       92 sec
# Unnamed: 14                            1
# Unnamed: 15                           -1
# Unnamed: 16                            0
# Unnamed: 17                      unknown
# Unnamed: 18                           no
# Name: 5, dtype: object

# %%
df.loc[9]
# Out:
# banking marketing                        8
# Unnamed: 1                              42
# Unnamed: 2                          120000
# Unnamed: 3                               2
# Unnamed: 4                        divorced
# Unnamed: 5           entrepreneur,tertiary
# Unnamed: 6                              no
# Unnamed: 7                             yes
# Unnamed: 8                             yes
# Unnamed: 9                              no
# Unnamed: 10                        unknown
# Unnamed: 11                              5
# Unnamed: 12                      may, 2017
# Unnamed: 13                        380 sec
# Unnamed: 14                              1
# Unnamed: 15                             -1
# Unnamed: 16                              0
# Unnamed: 17                        unknown
# Unnamed: 18                             no
# Name: 9, dtype: object

# %%
df.loc[35]
# Out:
# banking marketing                       34
# Unnamed: 1                              59
# Unnamed: 2                           20000
# Unnamed: 3                               0
# Unnamed: 4                         married
# Unnamed: 5           blue-collar,secondary
# Unnamed: 6                             yes
# Unnamed: 7                              no
# Unnamed: 8                             yes
# Unnamed: 9                              no
# Unnamed: 10                        unknown
# Unnamed: 11                              5
# Unnamed: 12                      may, 2017
# Unnamed: 13                        226 sec
# Unnamed: 14                              1
# Unnamed: 15                             -1
# Unnamed: 16                              0
# Unnamed: 17                        unknown
# Unnamed: 18                             no
# Name: 35, dtype: object
